# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import re

# %%
df = pd.read_csv('jobstreet_jobs.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#       Date Obtained                                               Link  \
# 0  04/05/2025 22:18  https://ph.jobstreet.com/job/83980792?type=sta...
# 1  04/05/2025 22:18  https://ph.jobstreet.com/job/83981404?type=sta...
# 2  04/05/2025 22:18  https://ph.jobstreet.com/job/83976786?type=sta...
# 3  04/05/2025 22:18  https://ph.jobstreet.com/job/83976299?type=sta...
# 4  04/05/2025 22:18  https://ph.jobstreet.com/job/83970409?type=sta...
#
#                                              Company  \
# 0                                   Mapúa University
# 1                                          Axos Bank
# 2                          WalterMart Community Mall
# 3                INFINITY SPORTS INTERNATIONAL, INC.
# 4  CITCO INTERNATIONAL SUPPORT SERVICES LIMITED-P...
#
#                              Position                   Location  \
# 0                        Data Analyst  Manila City, Metro Manila
# 1                        Data Analyst  Manila City, Metro Manila
# 2          Data Analyst | Quezon City  Quezon City, Metro Manila
# 3                        Data Analyst  Makati City, Metro Manila
# 4  Data Analyst (Alabang - Mid-shift)      Alabang, Metro Manila
#
#               Classification                                Industry  \
# 0  Business/Systems Analysts  Information & Communication Technology
# 1  Business/Systems Analysts  Information & Communication Technology
# 2  Business/Systems Analysts  Information & Communication Technology
# 3       Analysis & Reporting            Banking & Financial Services
# 4                      Other                              Accounting
#
#                         Salary Work Arrangement Day Posted
# 0                          NaN              NaN    13h ago
# 1                          NaN           Hybrid     1d ago
# 2                          NaN              NaN     1d ago
# 3  ₱25,000 – ₱30,000 per month              NaN     1d ago
# 4                          NaN           Hybrid     2d ago

# %% [markdown]
# ## Transformations to do:
#
# - Get job id from link ('/job/{job id}?') ✅
# - Split salary column into currency_salary, min_salary, max_salary ✅
# - Fill work arrangement na with 'Others' ✅
# - Add date posted from date obtained minus day posted ✅

# %% [markdown]
# ### Job ID

# %%
df['Job ID'] = df['Link'].str.split('/', expand = False).str[4]

# %%
df['Job ID'] = df['Job ID'].str.split('?', expand = False).str[0]

# %%
df.head()
# Out:
#       Date Obtained                                               Link  \
# 0  04/05/2025 22:18  https://ph.jobstreet.com/job/83980792?type=sta...
# 1  04/05/2025 22:18  https://ph.jobstreet.com/job/83981404?type=sta...
# 2  04/05/2025 22:18  https://ph.jobstreet.com/job/83976786?type=sta...
# 3  04/05/2025 22:18  https://ph.jobstreet.com/job/83976299?type=sta...
# 4  04/05/2025 22:18  https://ph.jobstreet.com/job/83970409?type=sta...
#
#                                              Company  \
# 0                                   Mapúa University
# 1                                          Axos Bank
# 2                          WalterMart Community Mall
# 3                INFINITY SPORTS INTERNATIONAL, INC.
# 4  CITCO INTERNATIONAL SUPPORT SERVICES LIMITED-P...
#
#                              Position                   Location  \
# 0                        Data Analyst  Manila City, Metro Manila
# 1                        Data Analyst  Manila City, Metro Manila
# 2          Data Analyst | Quezon City  Quezon City, Metro Manila
# 3                        Data Analyst  Makati City, Metro Manila
# 4  Data Analyst (Alabang - Mid-shift)      Alabang, Metro Manila
#
#               Classification                                Industry  \
# 0  Business/Systems Analysts  Information & Communication Technology
# 1  Business/Systems Analysts  Information & Communication Technology
# 2  Business/Systems Analysts  Information & Communication Technology
# 3       Analysis & Reporting            Banking & Financial Services
# 4                      Other                              Accounting
#
#                         Salary Work Arrangement Day Posted    Job ID
# 0                          NaN              NaN    13h ago  83980792
# 1                          NaN           Hybrid     1d ago  83981404
# 2                          NaN              NaN     1d ago  83976786
# 3  ₱25,000 – ₱30,000 per month              NaN     1d ago  83976299
# 4                          NaN           Hybrid     2d ago  83970409

# %%
df['Position'].unique()
# Out:
# array(['Data Analyst', 'Data Analyst | Quezon City',
#        'Data Analyst (Alabang - Mid-shift)',
#        'Data Analytics Associate - SeaBank', 'Data Engineer Team Leader',
#        'Manager, Data & Analytics, Data Engineer',
#        'Data Analyst - Contact Center',
#        'Full-Stack Engineer (for AI & Automation)',
#        'Data Science Specialist', 'Data Architect', 'ACTUARIAL ANALYST',
#        'Data Analytics Senior Analyst', 'BI/Data Science Analyst',
#        'Marketing Data Analyst', 'Data Engineer',
#        'Data Engineer (WFH | DAYSHIFT)', 'DATA ANALYST',
#        'Modelling and Data Science', 'Risk Data Science Manager',
#        'Senior Software Engineer (Data & Analytics)  Hybrid Set Up - 7 Days a Month',
#        'Data Engineer-Business Intelligence (Japanese Bilingual)',
#        'Cloud Data Engineer | Pioneer Account | Quezon City',
#        'Actuarial Analyst', 'Artificial Intelligence Specialist',
#        'Data Engineer | Project-based | Work From Home | Day Shift | Weekends Off',
#        'AI and Analytics Specialist', 'AI Data Architect',
#        'Senior Power BI Developer (6-Month Project Based)',
#        'Power BI Developer', 'Tableau Developer', 'AI Engineer',
#        'Data Modeling Manager | SQL, R, or Python',
#        'Data Modeling Specialist | SQL, R, or Python',
#        'Data Visualization Engineer', 'cloud Data engineer',
#        'Data Analyst (SQL Specialist)',
#        'Customer Experience Analyst (Speech, Text, Data Analytics)',
#        'AWS Data Engineer', 'Data Scientist (AI Specialist)',
#        'Research Analyst (On-site)',
#        'Report Analyst (Excel Macro) - ASAP',
#        'Data Analyst & Data Engineer (SQL) ASAP',
#        'Mid Data Scientist (Homebased)',
#        'Mid Machine Learning Engineer (Homebased)',
#        'Tableau Data Analyst', 'Data Analyst (BGC, Taguig)',
#        'Senior Lead Data Analyst', 'Machine Learning Engineer',
#        'Senior Statistical Specialist (SG-19, Job Order)',
#        'Data Engineer I', 'Analytics Engineer', 'Data Scientist',
#        'Data Analyst / Process Encoders (PROJECT BASED)',
#        'Data Scientist / Senior Pricing Specialist',
#        'Data Engineer Data Warehouse',
#        'Data Engineer - PowerBI (Work From Home / Dayshift)',
#        'Senior Power BI Developer (Project-Based)',
#        'Data Analyst (Tableau)', 'Data Modeler',
#        'Data Analytics Associate', 'Lead Data Engineer',
#        'Data Engineer - Data Warehouse', 'Senior Data Analyst',
#        'Data Engineer II (AWS, DBT, & PySpark Required) | Morning Shift',
#        'Business Intelligence Analyst',
#        'DATA ENGINEER (Hybrid, Twice a Month RTO Alabang, 2pm - 11pm)',
#        'Data Engineer-Data Platforms', 'Data Processing Analyst (L1)',
#        'Data Quality Analyst', 'Monitoring Analyst',
#        'Azure Data Engineer', 'Informatica PowerCenter Data Engineer',
#        'Data Science Manager', 'Data Analyst (Hadoop / Big Data)',
#        'Data Analyst III', 'Data Researcher, Estimates',
#        'Research Analyst - OPEN TO FRESH GRADUATE',
#        'Program Informatics Spec - Data Visualization | Onsite - Night Shift',
#        'Data Analyst (KYC)', 'Senior Data Analyst, SPX Express',
#        "Reports Analyst - World's Biggest Search Engine Account - CONCENTRIX TAGUIG",
#        'Actuarial Director', 'Data Operations Analyst',
#        'Data Engineer 4x onsite (1 day WFH)', 'Team Lead - Data Analyst',
#        '2025-7570_Data Analyst Junior',
#        'Data Analyst / Data Engineer (cloud) (wfh) (day shift)',
#        'Data Engineer (wfh) (day shift)',
#        'Senior Data Engineer – Microsoft Azure Data Services',
#        'Risk and Data Analyst',
#        'Business Intelligence Engineer - Hybrid, Nightshift',
#        'Data Analyst (Knowledge Management)',
#        'Lead Data Engineer - Informatica MDM',
#        'URGENT! Senior Data Engineer (w SQL & Tableau, DBT exp) - Onsite',
#        'Senior Data Scientist', 'Senior Data Engineer',
#        'Power BI Analyst/Developer - Automation Focus',
#        'Freelancers Needed for AI & LLM Projects',
#        'Data Analytics Officer', 'Data Engineer (Databricks & On-prem)',
#        '2025-7558_Actuarial Analyst',
#        '2025_7563_Software Engineer Level II/III',
#        'DE027775 - Analytics and Modeling Senior Analyst',
#        'DE027776 - Analytics and Modeling Analyst',
#        'Senior Machine Learning (ML) Data Engineer', 'BI Tech Lead',
#        'Data Analyst (Night Shift)',
#        'Data Analyst (Trends Analysis and Reporting)', 'Informatica MDM',
#        'Data Analyst - Manager (NIGHT SHIFT)',
#        'Data Scientist - Telecommunications',
#        'Senior Data Scientist - Financial Services',
#        'Senior Data Engineer – Azure Platform', 'Analytics Specialist',
#        'Data Analyst Engineer', 'Senior Azure Data Engineer (Remote)',
#        'Data Management Specialist', 'Data and Report Coordinator',
#        'Data Analyst - People Analytics | Night Shift | 5 months fixed term',
#        'Data and Reporting Analyst (PowerBi) | Alabang/ Pasay/ QC/ Taguig (Hybrid)',
#        'Data Operations Analyst | Hybrid', 'Product Catalog Analyst',
#        'Sr. Business Intelligence Analyst', 'Data Analyst (PowerBI)',
#        'Business Analysis Professional (Data Analyst & Reports Developer)',
#        'Business Analytics Specialist', 'Data Analytics Assistant',
#        'Sr. Data Analyst',
#        'Research Analyst - FactSet Fundamentals (Hybrid)',
#        'Data Analyst | Onsite in BGC | Morning Shift',
#        'Data Analyst (PowerBI & Excel proficient) | Shaw On Site | Night Shift',
#        'Tableau Expert  BI Analyst', 'Data Governance Analyst',
#        'Power BI - Data Integration Support', 'Community Data Analyst II',
#        'I.T. DATA SCIENTIST (SENIOR)', 'I.T. Data Engineer',
#        'Data Analyst Manager (Analytics and Visualization)',
#        'Research Analyst', 'Research Analyst - Corporate Transactions',
#        'Data Architect (Databricks Certified Data Engineer)',
#        'Microsoft Cloud Data Engineer – Azure & Fabric',
#        'Junior Cloud Data Engineer', 'Jr. Data Analyst',
#        'SAS DATA ENGINEER', 'Data Modeling Techniques and Methodologies',
#        'Data Engineer (Microsoft Fabric)', 'Data Support Specialist',
#        'PROCESS ENCODERS', 'Data Analytic Engineer',
#        'Tier 2 Data Analyst/Programmer', 'Senior Azure Data Engineer',
#        'Tier 1 Data Analyst/Programmer', 'Senior Cloud Data Engineer',
#        'ECL Data Analyst', 'Collections Data Analyst (Hybrid)',
#        'Data Scientist and Analyst Manager', 'Data Analyst - SQL/PowerBI',
#        'Data Scientist (Japanese Bilingual) - AET',
#        'Data Engineer (AWS) - Hybrid set up',
#        'Business Intelligence (BI) Developer (wfh) (day shift)',
#        'Statistical Analyst (Fresh Grad - Statistical, Social Science, & Actuarial)',
#        '2025-7567_Actuarial Analyst - Mid', 'French Data Analyst',
#        'Junior Financial Data Analyst',
#        'Data Analyst (Open for Fresh Graduates)',
#        'Data & AI - Data Modeler',
#        'Finance Research Analyst  (OPEN to Fresh Graduates)',
#        'Retail Data Analyst', 'Market Data Engineer',
#        'Data Engineer (Azure) - Work from home (VNG)',
#        'Data Architecture Senior Analyst | Data Analytics',
#        'Data Analytics | PowerBi, Python and AWS experience',
#        'HEAD OF DATA SCIENCE AND ANALYTICS', 'Big Data Engineer',
#        'Business Data Analyst',
#        'Web Research Analyst | Hybrid Setup | Pasay | ASAP',
#        'AVP, Risk Model Sr. Analyst (Hybrid)', 'Cloud Data Engineer',
#        'ML & Search Engineer', 'Actuarial Data Analyst - Remote',
#        'Senior Data Analyst | Mandaluyong | BPO',
#        'Lead/Senior Data Scientist - WFH', 'Full Stack Data Scientist',
#        'Data Visualization Developer',
#        'Power BI Developer | Day 1 HMO | Night Shift | Onsite | NCR | Weekends Off',
#        'Data Engineer (WFH/DAYSHIFT)',
#        'Data Analyst III (Salesforce-focused)',
#        'Media Analytics Specialist',
#        'Actuarial Senior Analyst/Assistant Actuarial Manager',
#        'Senior Report Writer/Data Engineer - Ortigas',
#        'Research Analyst (Open to Fresh Graduates) - Onsite Setup (A)',
#        'Senior Data Engineer hybrid from Manila, Philippines',
#        'Data Analyst (SQL, DBeaver)', 'Offshore Data Analyst',
#        'Data Analyst - Python', 'Data Management Analyst',
#        'Data Engineer | KMC FBG Philippines', 'Shopify Developer',
#        'Data Analytics & OR Analyst', 'Business Intelligence',
#        'Director of AI Platform', 'Data Analyst Operation Support',
#        'BI Developer (Tableau)', 'Data Engineer II', 'Data Specialist',
#        'Research Analyst - USM (May start date)', 'Master Data Engineer',
#        'Research Analyst (WFH/Remote)', 'Junior Business Analyst',
#        'Telemarketing Data Analyst',
#        'Senior SQL Developer (Remote / Night Shift)',
#        'Business Intelligence Analyst (WFH/Hybrid)',
#        'CRM / Data and Analytics Specialist',
#        'Data Scientist Lending Analytics', 'Business Intelligence Expert',
#        'R0005683: Data Scientist', 'Data Analyst - Hybrid Setup',
#        'Compensation Data  Research Analyst (Hybrid/Night Shift)',
#        'Data Analyst - ETL', 'Research Analyst- Open for Fresh Graduate',
#        'Sr. Analyst, HR Data Operations',
#        'Data and AI Associate Director',
#        'Data Architect - Databricks Certified Data Engineer',
#        'Data Analyst | Onsite Set up', 'Model Validator',
#        'Application Developer Power BI - Hybrid Muntinlupa',
#        'AI Model Specialist & Developer',
#        'DATA ANALYST (Workplace Strategies Associate)',
#        'Research Analyst - Funds (to start on May 2025)',
#        'Regulatory Risk Associate', 'CRM Analyst',
#        'Decision Sciences Associate (Statistician)',
#        'Data Engineer-Business Intelligence',
#        'Data Engineer-Data Platforms-Google',
#        'Compliance Data Analyst (SQL & Python)',
#        'Data Engineer | Hybrid After 6 Months | BGC',
#        'Business Data Analyst (PowerBI & MongoDB expert)',
#        'Data Engineer (Python, SQL, AWS or Azure)',
#        'Data Engineer-Data Warehouse',
#        'HIRING! Actuarial Analyst - BGC (Night Shift)',
#        'Data Analyst (Digital Marketing)',
#        'HubSpot Specialist & Data Statistician',
#        'Associate Data Scientist | Temporary WFH | Makati | Night Shift | Day 1 HMO',
#        'Cloud Data Engineer (Azure & Fabric, SQL/Python) | Dayshift AU',
#        '2025-7549_Data Engineer Mid',
#        'Research Analyst (Open to any business course) - June 2025',
#        'Full Stack Data Scientist (open to Fresh Graduates)',
#        'Lead Data Architect - Databricks Certified Data Engineer',
#        'AI/ML Engineer', 'Business Intelligence Developer',
#        'Customer Success Data Analyst', 'Data Engineer (WFH)',
#        'Research Analyst - Revere', 'Data Coder  Analyst / Book Keeper',
#        'Junior Data Engineer (at least 1 yr Datastage exp) | Cebu/Manila (Hybrid)',
#        'Senior Data Engineer - Python | Manila (Hybrid/Dayshift)',
#        'Lead Data Engineer - Python (Hybrid/Dayshift) | Cebu/Manila',
#        'Power BI Developer - Alabang',
#        'Data Analyst (AU Financial Services)',
#        'Senior Technical Data Analyst',
#        'Data Science Specialist (Hybrid Setup)',
#        'Instrument Data Management - Intern',
#        'TD Salesforce CPQ Data Analyst',
#        'Requisition Title Technical Consultant-3', 'Data Analyst II',
#        'Data Engineer (Hybrid Cloud, Reporting, and Visualization)',
#        'Analyst, Data Acquisition', 'Data Analyst - Mid/Senior',
#        'Product Data Analyst - Index Contributor Partnerships',
#        '2024-7457_Business Operations Analyst',
#        '2025-7537_Data Scientist Senior', '2025-7551_Data Scientist Mid',
#        'BI Developer', 'Statistical Forecaster',
#        'DE027644-Analytics Specialist',
#        'Junior Analyst, Quantitative Modeling and Data Mastering',
#        '2024-7328_Intelligent Document Processing Data Scientist Senior',
#        'Business Intelligence Analyst | Onsite ANE, Makati | ASAP | Salesforce & Tableau',
#        'Enterprise Analytics Specialist', 'Globe Data Analytics Bootcamp',
#        'Senior Advanced AI Engineer', '2025-7546_Operations Analyst',
#        'Data Engineer / Data Streaming', 'Senior Research Analyst',
#        'Deputy Manager - Operations (Data Engineer)',
#        'Data Engineering Analyst', 'Data Analyst | Up to 50K Salary',
#        'Data Analyst (Financial) DO- 03052025- FTDA',
#        'Data Engineer (AU Retail, Hybrid)', 'Jr. MDI Analyst',
#        'AI/ML Technical Lead', 'SENIOR DATA ENGINEER', 'AI DEVELOPER',
#        'MACHINE LEARNING ENGINEER', '2025-7490_Data Analyst',
#        'Data Processing Specialist', '2025-7481_Actuarial Analyst',
#        'Data Analyst - Consumer', 'Data Analytics', 'Actuarial Analyst-1',
#        'Sales Excellence - COE - Advanced Modeling Specialist',
#        '2024-7402_Data Scientist', 'Senior MLOps',
#        'SAP Master Data Application Engineer',
#        'ANALYST II DATA GOVERNANCE',
#        'Data Analyst with experience in F2P Games',
#        'Insighting and Report Manager', 'Power BI Developer (BPO)',
#        'DE026525- Analytics Advisory Senior Analyst',
#        'Sr. Actuarial Analyst/ Assistant Manager', 'Reports Analyst',
#        'Senior Applied AI Scientist', 'Data Scientist (Mid Level)',
#        'Data Quality Engineer', 'Principal Data Scientist',
#        'AP-Data Analyst', 'Data Integration Engineer',
#        'Data Visualization Specialist', 'Data Engineer (AWS)',
#        'Head of Actuarial Analytics and Transformation',
#        'Data Analyst/Data Engineer (Fully Remote)',
#        'Data Analyst, Benefits Data Source (Morning Shift) - Open for Fresh Graduates',
#        'Data Analyst, Reporting and Analytics (Night Shift) - Open for Fresh Graduates',
#        'Data Analyst ( CBE Specialist)', 'Data Specialist I',
#        'Data Engr. (IT)', 'Data Engineer (Hybrid)',
#        'MIS/Data Specialist (UK Client) - Muntinlupa',
#        'AI Machine Learning Scientist - Senior',
#        'Data Analytics Specialist', 'Officer - Risk Management',
#        'Sr. Risk Analyst (Project Hire)',
#        'Jr. Risk Analyst (Project Hire)',
#        'TABLEAU DEVELOPERS (PROJECT BASED)', 'DATA ENGINEER',
#        'POWER BI DEVELOPER', 'Data Analytics | Python and AWS experience',
#        'Data Engineer : Data Modelling',
#        'Data Engineer Lead (Data Modeler)',
#        'Data Engineer (SQL) | WFH | DAYSHIFT',
#        'Associate Data Scientist | Temporary WFH | Makati | Night',
#        'Power BI Developer | WFH | Day Shift | Weekends Off',
#        'Research and Data Analyst | Hybrid | Makati/Ortigas',
#        'Senior Machine Learning Engineer',
#        'Data Analytics Officer (Operational Analytics)',
#        'Data Analyst (Dayshift Schedule / Fixed Weekends Off)',
#        'Senior/Middle Data Engineer', 'Data Platform Engineer',
#        'Senior BI Developer', 'Financial Research Analyst',
#        'LLM Engineer', 'Senior Data Engineer (Hybrid)',
#        'Data Analyst - Mid/Senior (Bench)',
#        'DATA ANALYTICS OPERATIONS OFFICER',
#        'Power BI Developer/ Fulltime',
#        'Actuarial Analyst/Senior Analyst/Manager',
#        'Data Analyst - Homebased', 'Reports Developer',
#        'Financial Data Analyst', 'Sr. Data Science Engineer',
#        'Senior Analyst Data Visualization - Taguig',
#        'Power BI Developer (Project Hybrid) - Pasay City',
#        'Tableau Developer - Pasay City', 'Data Engineer - Pasay City',
#        'Data Engineer/Fulltime', 'Data Analytics & Data Modeler_Contract',
#        'Data Modeling Techniques and Methodologies Consultant',
#        'Data Engineer _ 3 months contract with possible extension',
#        'Microsoft Azure Data Services Engineer',
#        'Distribution Development Specialist (Fixed-term)',
#        'Jr. Data Analyst (open to fresh grads - Mid Shift )',
#        'Data Analyst | WFH | Day Shift | Day 1 HMO | Weekends off',
#        'Data Engineer | PHP140K | Sign-On Bonus | Hybrid | Day Shift',
#        'Data Analyst | Hybrid in BGC', 'Data Analyst (Mid Shift)',
#        'Junior Data Engineer', 'Economist (Data Science)',
#        'Japanese Bilingual Data Scientist',
#        'Market Data Engineer - Financial Markets/Tradings - 4 Headcounts',
#        'Model Development Manager', 'Operations Business Data Analyst',
#        'Data Engineer-Data Warehouse (Japanese Bilingual)',
#        'Data Analyst (Advanced MS Excel)', 'Principal AI Engineer',
#        'Senior Data Engineer (Talend ETL Developer)',
#        'Data Analyst & Systems Coordinator',
#        'SQL Data Analyst (WFH/Onsite - Nightshift)',
#        'Data Analyst - Python | PowerBi, Tableau, Looker',
#        'Cloud Data Engineer (Immediate Joiner!)',
#        'DATA SCIENTIST (HMO w/ 4 FREE Dependents, Insurance, Medical Reimbursement)',
#        'Data Science Senior Analyst (Data Analytics)',
#        'Financial Data Analyst - Corp',
#        'Analytics Specialist | Python and AWS experience',
#        'Data Engineer (Hybrid-Day Shift)',
#        'GBS Data & Analytics Specialist', 'Jr. Power BI Developer',
#        'Data Scientist (Product Management)',
#        'Product Management and Data Sr. Analyst',
#        'Product Portfolio Management Consultant (Actuarial Consultant)',
#        'Table developer', 'Senior Data Analyst - Dataiku',
#        'Data Analyst - Senior Level (Managerial)',
#        'Data Engineer II - Cloud Technologies (Hybrid)',
#        'Data Engineer Support (JR)', 'DATA GAMING ANALYST',
#        'Data Engineer Director', 'Data Analyst (ETL and SQL)',
#        'Variable Data Printing Specialist', 'Data Insights Analyst',
#        'Data Scientist_Python, Tableau_ REMOTE _1 year contract',
#        'Power BI Developer (Mandaluyong)', 'Data Engineer (Pasay City)',
#        'Tableau Developer (Pasay City)', 'Data Engineer Support',
#        'Data Analytics Executive', 'Data Architect Senior Manager',
#        'Data Analyst I 1032 Work From Home', 'Data Engineer|Platform',
#        'Senior Data Engineer – Cloud & Data Warehousing',
#        'Senior Lead Analyst Business Intelligence', 'MID DATA ANALYST',
#        'Data Analyst | Permanent WFH | Day Shift | Day 1 HMO',
#        'Azure Data Engineer (Microsoft Azure Data Services)',
#        'Microsoft Azure Data Services - Senior Engineer',
#        'Customer Experience Analyst (Speech/Data Analytics)',
#        'Generative AI', 'Compliance Data Analyst',
#        'Data Analyst | Google Analytics & Ecommerce EXP |   Hybrid Pasig',
#        'Data analyst', 'Data Analyst - Hybrid',
#        'Data Engineer (Mid-Senior)', 'Qlik Data Analyst',
#        'Business Intelligence Developer (Hybrid)',
#        'Research Analyst (Fresh graduates of business courses) - June 2025',
#        'Data Scientist (Mid-Shift)', 'AI Analyst',
#        'Cloud Data Engineer (Quezon City)',
#        'Cloud Data Engineer - Quezon City', 'Data Engineering Expert',
#        'Metrics & Reporting Senior Associate / 1+ year experience in SQL and Python',
#        'Data and Reports Analyst | Concentrix Bridgetowne',
#        'Model Developer',
#        'Junior Data Engineer | Hybrid | Makati | Semi-Flexible Shift',
#        'Senior Data Scientist (Power BI, Python and Cloud Technologies)',
#        'Data Analyst (MX PM)',
#        'Senior Data Analyst (Data Hygiene Specialist)',
#        'Business Intelligence Analyst (Mandaluyong City)',
#        'Data Analysis Specialist | SQL, R, or Python',
#        'Junior Data Engineer - Databricks',
#        'Data Analyst (SQL/Advance Excel)', 'Dataiku',
#        'Data Engineer | Project-Based | WFH | Day Shift',
#        'Specialist I Master Data Management', 'Inventory Data Analyst',
#        'Senior Data Engineer (SQL, Tableau, DBT experience)',
#        'Analytics Specialist | PowerBi, Python and AWS experience',
#        'Analytics Manager | SQL, R, or Python',
#        'Data Analyst (w/ Salesforce CPQ exp REQUIRED) - Onsite/Hybrid',
#        'Data Engineer (Jr to Mid Level)', 'Data Analyst- Makati',
#        'Mid/ Sr. Data Engineer (Spark + Big Query) | Work from Home*',
#        'Technical Associate - AI / Data Annotator',
#        'Urgent: Data Engineer (Onsite)',
#        'Data and Analytics Admin (MX - SPI)',
#        'Junior Data Analyst (Data Collection and Verification)',
#        'Power BI Report Developer', 'PDM Data Analyst',
#        'Data Analyst (Remote PH)',
#        'Business Reporting Analyst (HRIS)_REMOTE_1 year contract',
#        'Cloud Data Engineer - 5 Yrs Exp - 70K/Makati',
#        'SENIOR DATA ENGINEER (Hybrid, Twice a Month RTO Alabang, 2pm - 11pm)',
#        'Senior Data Engineer - IBM InfoSphere DataStage',
#        'Workday Reporting Associate Consultant',
#        'Business Data Analyst | Paranaque',
#        'Sustainability Data Analyst - Python',
#        'DATA ANALYST | BGC TAGUIG', 'DATA ENGINEER | PIONEER ACCOUNT',
#        'Data Science Practitioner',
#        'Tableau Developer(2-5 years experience)  - Remote',
#        'BUSINESS ANALYTICS HEAD',
#        'Business Intelligence Analyst (Pooling)',
#        'Data Science Senior Analyst',
#        'Sr. Azure Data Engineer (Malaysia)', 'Technical Data Analyst',
#        'Gen AI', 'Azure Senior Data Engineer (Malaysia)',
#        'Investment Portfolio Data Integration Analyst',
#        'Data Analytics Specialist | AWS and Python',
#        'Intern - Data Scientist', 'Configuration Analyst (SQL/Python)',
#        'BUSINESS ANALYTICS OFFICER', 'DATA ANALYST (URGENT HIRING)',
#        'Data Analyst | Data Engineer | Pioneer Team',
#        'AI/Machine Learning Engineer', 'Sr. Data Scientist',
#        'Cloud Data Engineer (Hybrid Work/Graveyard/US Holidays)',
#        'Data Analytics Specialist | SQL, R, or Python',
#        'BI Developer (w/ Python programming experience)',
#        'Research Analyst (Skills Gap)',
#        'Analytics Specialist | AWS and Python',
#        'Cloud Data Engineer for ComputerInformation Technology/70k/Makati',
#        'Lead Consultant - Data Architecture & Engineering (GDC) - Remote',
#        'Data Analyst | Onsite Makati | Nightshift (M-F)',
#        'CREDIT DATA ANALYST',
#        'Customer Operation Assistant (Data Analyst)',
#        'Business Intelligence Lead (Power BI Specialist)',
#        'RR-0172213 Data and AI PH - P&G - Senior Analyst I Data Engineering',
#        'Data Science / Technical Analyst',
#        'Data Analyst - Billing Telco (WFH - Day Shift)',
#        'Senior Artificial Intelligence Stacker',
#        'Data Analyst with JLPT N3 Passer (Japanese)',
#        'Credit Data Analyst (KYC)', 'Data Analyst Officer',
#        'BILLING ANALYST (telco) (SQL) (data analysis) (wfh) (day shift)',
#        'Data Engineer-Business Intelligence/Data Warehouse (Japanese Bilingual)',
#        'Data Analyst (Hybrid Setup)',
#        'Sr. Data Engineer (Python and AWS) - Remote set up',
#        'Data & Analytics Intern',
#        'Data and Billing Analyst - SQL and Telco Background',
#        'Senior Data & Business Intelligence Specialist',
#        'AI Specialist (Remote)', 'Data Analyst - Data Operations',
#        'Investment Portfolio Data Integration Analyst - Open for Entry Level',
#        'EOI: Data Sr. Analyst', 'Senior Data Analyst / Engineer',
#        '2025-7593_Data Engineer - Mid', 'Lead Data Scientist',
#        'Associate Data Engineer', 'Analyst, Research',
#        'Data Engineer (Azure Cloud) - ONSITE',
#        'Data Engineer - Azure Cloud/Python (Onsite-Contract)',
#        'Data and MI Manager',
#        'Senior Data Engineer | Hybrid | Day Shift | Day 1 HMO',
#        'Research Analyst - Equity Research APAC',
#        'Associate Manager, Data & Analytics, Data Engineer',
#        'Sr. Analyst, Data Analysis',
#        'DATA SCIENCE ENGINEER (PIONEER ACCOUNT)',
#        'Quantitative Research Scientist', '2025-7559_Actuarial Analyst',
#        'Prompt Engineers',
#        'Commercial Operations Analyst (Data Analyst, SQL)',
#        'Data Analyst (Project-based)', 'Research Manager',
#        'Specialist Data Analyst', 'Pr. Analyst, Data Analysis',
#        'Data Analyst - Reporting (Mid Shift)', 'Language Data Scientist',
#        'Risk Modeler', 'DATA SCIENTIST',
#        'Data Analyst (SQL, Tableau, Excel) Work from home',
#        'Data Analyst / Engineer',
#        'Senior Data Analyst/Visualization Engineer',
#        '2024-7328_Data Scientist Senior (AI and Automation IDP)',
#        'Data Analyst Lead l HYBRID l Apply Now!',
#        'Quality Data Analyst - Onsite/Night Shift (Makati)',
#        'Data Engineer - Snowflake Data Warehouse',
#        'Cloud/Enterprise Data Architect',
#        'Data Engineer - Databricks Administrator',
#        'Competitive Strategy Analyst',
#        'Lead Software Engineer (Azure Databricks and Python',
#        'Package Consultant Workday Reporting & BI',
#        '(HYBRID) Finance Data Analytics Supervisor | Teleperformance Ayala',
#        'Data Strategy Consultant (PowerBI and AI)',
#        'Data Analyst (Power BI) - Hybrid/WFH',
#        'Data Engineer - UP to 85K - Ortigas',
#        'Data Modeler - WFO Makati/Angeles', 'Risk Analytics Officer',
#        'Data Scientist (with AI Models experience)',
#        'Data Engineer (AU Global Education Services, Hybrid)',
#        'DATA ENGINEER | Pioneer Account | Quezon City',
#        'Senior Workforce Management Analyst - Data Scientist',
#        'BI Reporting Analyst', 'Data Engineer - 68248 (100% ONSITE)',
#        'Data Architect (Senior)',
#        'Data Analyst | Dayshift & Weekends Off',
#        'Junior Business Intelligence Analyst', 'AI Data Engineer',
#        'Data Integrity Analyst (Healthcare)',
#        'Senior Workforce Management Analyst (Data Scientist)',
#        'Data Admin Engineer - Snowflake Data Warehouse',
#        'Data Admin Engineer - Databricks Unified Data Analytics Platform',
#        'Data Analytics (Campaign Analyst)',
#        'Senior WFM Analyst (Work-from-Home) – Data Science Role',
#        'Professional, BI Data Engineer (TCF)',
#        'Market Insight Data Analyst (SQL, Tableau, Excel) Work from home',
#        'AI & Data - Data Science Senior Manager', 'Sales Data Analyst',
#        'Data Engineer - Hybrid (Thrice a week onsite) - Mid shift - Min. 3 years exp',
#        '2025-7603_Data Scientist Senior', 'CRM Data Analyst',
#        'Data Engineer (Back-End)', 'Data Engineer (Azure & MS Fabric)',
#        'Manager – Data Science & Predictive Operations',
#        'NetSuite Data Analyst', 'Snowflake Administrator - Data Engineer',
#        'Data Engineer (Databricks Administrator)',
#        'Consumer Connections and Insights Manager',
#        'Gen AI Developer - C1',
#        'Lead Data Architecture & Engineering Consultant (GDC) - WFH',
#        'BI Developer (w/ strong experience in Tableau)',
#        'Start ASAP! Data Analyst (Hybrid) | Dayshift | 12 months project-based',
#        'Data Analyst | In Office BGC, Taguig', 'Technical Specialist',
#        'Data Platform Engineer (Big Data / Cloud / ETL)',
#        'Data Engineer (Microsoft Stack – On-Prem & Azure) - Remote / UK Hours',
#        'Associate Statistics Officer (Data Science)', 'Data AnalystNew',
#        'Data Analytics Scientist (Alteryx)',
#        'Data Engineer II (DBT, & PySpark Required) | Morning Shift',
#        'Data Engineer / Sr. Data Analyst l Hybrid l Uptown, Taguig l APPLY NOW!',
#        'Reporting/Data Analyst | Mid Shift | Work Onsite in Pasig',
#        'Data Visualization Expert l Hybrid l Uptown, Taguig l APPLY NOW!',
#        'Data Analyst/ETL Developer',
#        'SENIOR DATA ENGINEER (ETL, TALEND) -- URGENT',
#        'Data Quality Analyst (Excel Expert)',
#        'Urgent Hiring: Junior Business Analyst',
#        'Data Analyst (Finance Analytics and Reporting)',
#        'Python Data Engineer',
#        'Data Analyst Tech Lead l HYBRID l Apply Now!',
#        'Senior Retirement Specialist (Actuarial)',
#        'Campaign Operations and Analyst (Data Analytics - Alteryx)',
#        'Cloud Data Engineer (Quezon City',
#        'Senior Market Data Analyst (Programming Experience)',
#        'Business Analyst (Analytics) - Onsite Work Type',
#        'ETL Data Engineer/Analyst', 'Statistical Programmer',
#        'Market Research Manager',
#        'Data Analyst, Benefits Data Source (Night Shift)',
#        'Data Science and Analytics Intern (Statistics, Business Finance)',
#        'Excel Data Analyst', 'Data & Analytics - Systems Analyst (MDM)',
#        'Data Scientist Mid', 'Data Scientist Junior',
#        'Data Analyst - Collections',
#        'Data Analyst (AU Construction, WFH)',
#        'Senior Data Engineer with AWS', 'Sr. Data Specialist',
#        'Data & Integration Analyst', 'Senior Reports Developer',
#        'AI & Data Science Senior Manager_Strong with AI, consulting background is a MUST',
#        'Senior Data Analyst w/ Lead experience',
#        '3464 - Data Analytics Analyst',
#        'Databricks Unified Data Analytics Platform',
#        'Data Engineer (with DevOps Experience)',
#        'Data Engineer (Databricks and AWS)',
#        'Offshore Data Analyst (Remote)',
#        'Data Integrity Analyst- Hybrid- PH Night Shift',
#        'Data Analyst I- Hybrid-PH Night Shift',
#        'Data Analyst Team Lead | In-Office BGC, Taguig',
#        'Data Analyst (A - OH)', 'Solutions Consulting Manager for AI',
#        'Senior Solutions Data Analyst', 'Solutions Data Analyst',
#        'E-Commerce Sr. Data Analyst | Hybrid',
#        'Product Catalog Analyst - Booking Route Management',
#        'Junior Power BI Developer',
#        'Sr Data Engineer (AWS) - Hybrid set up',
#        'Supply Chain Data Analyst | BGC', 'Data Specialist (Midshift)',
#        'Data Analyst (Reporting & Insights Focus)',
#        'Research Analyst Hiring',
#        'Data Engineer (Admin) - Databricks Unified Data Analytics Platform',
#        'Cloud AI / Machine Learning (ML) Engineer',
#        'Analytics Engineer (US)',
#        'Lead Consultant - Data Architect & Engineer (Azure) - WFH',
#        'Mid-Level Data Scientist - Financial Services',
#        'Microsoft Azure Data Services',
#        'ESG Data Analyst (Mandarin Speaker)',
#        'Data Analyst | BGC Taguig City',
#        'Microsoft Cloud Data Engineer Azure/Fabric',
#        'Senior Data Engineer & DevSecOps', 'DATA ENGINEER | BGC TAGUIG',
#        'BIG DATA ENGINEER', 'Business Insights Analyst',
#        'Aviation Data Analyst I', 'Data & Analytics - Data Engineer',
#        'Internal Auditor- Data Analyst',
#        'Data Engineer - Team Lead - Direct Hire',
#        'Data Engineer (On-Prem)', 'AI / ML Engineer'], dtype=object)

# %% [markdown]
# ### Work Arrangement

# %%
df['Work Arrangement'].unique()
# Out:
# array([nan, 'Hybrid', 'Remote'], dtype=object)

# %%
df['Work Arrangement'] = df['Work Arrangement'].str.title().fillna('Other')

# %%
df.head()
# Out:
#       Date Obtained                                               Link  \
# 0  04/05/2025 22:18  https://ph.jobstreet.com/job/83980792?type=sta...
# 1  04/05/2025 22:18  https://ph.jobstreet.com/job/83981404?type=sta...
# 2  04/05/2025 22:18  https://ph.jobstreet.com/job/83976786?type=sta...
# 3  04/05/2025 22:18  https://ph.jobstreet.com/job/83976299?type=sta...
# 4  04/05/2025 22:18  https://ph.jobstreet.com/job/83970409?type=sta...
#
#                                              Company  \
# 0                                   Mapúa University
# 1                                          Axos Bank
# 2                          WalterMart Community Mall
# 3                INFINITY SPORTS INTERNATIONAL, INC.
# 4  CITCO INTERNATIONAL SUPPORT SERVICES LIMITED-P...
#
#                              Position                   Location  \
# 0                        Data Analyst  Manila City, Metro Manila
# 1                        Data Analyst  Manila City, Metro Manila
# 2          Data Analyst | Quezon City  Quezon City, Metro Manila
# 3                        Data Analyst  Makati City, Metro Manila
# 4  Data Analyst (Alabang - Mid-shift)      Alabang, Metro Manila
#
#               Classification                                Industry  \
# 0  Business/Systems Analysts  Information & Communication Technology
# 1  Business/Systems Analysts  Information & Communication Technology
# 2  Business/Systems Analysts  Information & Communication Technology
# 3       Analysis & Reporting            Banking & Financial Services
# 4                      Other                              Accounting
#
#                         Salary Work Arrangement Day Posted    Job ID
# 0                          NaN            Other    13h ago  83980792
# 1                          NaN           Hybrid     1d ago  83981404
# 2                          NaN            Other     1d ago  83976786
# 3  ₱25,000 – ₱30,000 per month            Other     1d ago  83976299
# 4                          NaN           Hybrid     2d ago  83970409

# %% [markdown]
# ### Salary Parsing to Salary Range

# %%
df['Salary'].unique()
# Out:
# array([nan, '₱25,000 – ₱30,000 per month', '₱25,000 – ₱35,000 per month',
#        '₱80,000 – ₱85,000 per month', '₱130,000 – ₱140,000 per month',
#        '₱120,000 – ₱145,000 per month', '₱60,000 – ₱80,000 per month',
#        '₱40,000 – ₱50,000 per month', '₱100,000 – ₱150,000 per month',
#        '₱50,000 – ₱70,000 per month', '₱38,000 – ₱48,000 per month',
#        '₱80,000 – ₱90,000 per month', '₱30,000 – ₱45,000 per month',
#        '₱30,000 – ₱35,000 per month', '₱100,000 – ₱130,000 per month',
#        '₱100,000 – ₱120,000 per month', '₱59,260 per month',
#        '₱70,000 – ₱85,000 per month', 'Budget - 90,000 to 100,000 PHP',
#        '₱95,000 – ₱100,000 per month', '₱95,000 – ₱140,000 per month',
#        '₱70,000 – ₱100,000 per month', '₱120,000 – ₱180,000 per month',
#        '₱24,000 – ₱30,000 per month', 'PHP 50,000 - 70,000',
#        '₱150,000 – ₱200,000 per month', '₱80,000 – ₱120,000 per month',
#        '₱80,000 – ₱100,000 per month', '₱45,000 – ₱55,000 per month',
#        '₱120,000 – ₱160,000 per month', '₱19,000 – ₱20,000 per month',
#        '₱110,000 – ₱150,000 per month', '₱53,000 – ₱63,000 per month',
#        '₱60,000 – ₱69,000 per month', '₱32,000 – ₱42,000 per month',
#        '₱85,000 – ₱100,000 per month', '₱100,000 – ₱140,000 per month',
#        '₱22,000 – ₱23,000 per month', '₱90,000 – ₱135,000 per month',
#        '₱120,000 – ₱130,000 per month', '₱130,000 – ₱150,000 per month',
#        '₱26,000 – ₱29,000 per month', '₱18,000 – ₱20,000 per month',
#        '₱150,000 – ₱180,000 per month', '₱150,000 – ₱170,000 per month',
#        '₱70,000 – ₱90,000 per month', '₱90,000 – ₱130,000 per month',
#        '₱35,000 – ₱50,000 per month', '₱65,000 – ₱90,000 per month',
#        '₱30,000 – ₱40,000 per month', '₱45,000 – ₱50,000 per month',
#        '₱35,000 – ₱45,000 per month', '₱50,000 – ₱75,000 per month',
#        '₱60,000 – ₱90,000 per month', '₱20,000 – ₱30,000 per month',
#        '₱73,333 – ₱105,000 per month', '₱105,000 – ₱120,000 per month',
#        '₱35,000 – ₱40,000 per month', '₱45,000 – ₱60,000 per month',
#        '₱34,000 – ₱50,000 per month', '₱70,000 – ₱80,000 per month',
#        '₱20,000 – ₱23,000 per month', '₱90,000 – ₱100,000 per month',
#        '₱40,000 – ₱45,000 per month', '₱60,000 – ₱70,000 per month',
#        'PHP 50,000 to PHP 80,000', '₱50,000 – ₱55,000 per month',
#        '₱25,000 – ₱32,000 per month', '₱40,000 – ₱60,000 per month',
#        '₱120,000 – ₱150,000 per month', '₱55,000 – ₱60,000 per month',
#        '₱100,000 – ₱110,000 per month', '₱25,000 – ₱28,000 per month',
#        '₱75,000 – ₱90,000 per month', '₱40,000 – ₱55,000 per month',
#        '₱60,000 – ₱75,000 per month', '₱280,000 – ₱300,000 per month',
#        '₱47,000 – ₱70,000 per month', '₱17,000 – ₱18,000 per month',
#        '₱18,000 – ₱22,000 per month', '₱200,000 – ₱240,000 per month',
#        '₱90,000 – ₱110,000 per month', '₱18,000 – ₱25,000 per month',
#        '₱24,000 – ₱25,000 per month', '₱80,000 – ₱110,000 per month',
#        '₱50,000 – ₱60,000 per month', '₱20,000 – ₱25,000 per month',
#        '₱18,000 – ₱18,720 per month', '₱25,000 per month',
#        '₱18,000 – ₱27,000 per month', '₱80,000 – ₱95,000 per month',
#        '₱60,000 – ₱85,000 per month', '₱93,000 – ₱103,000 per month',
#        '₱140,000 – ₱156,000 per month', '₱20,000 – ₱24,000 per month',
#        '₱55,000 – ₱65,000 per month', '₱27,000 – ₱30,000 per month',
#        '₱32,000 – ₱34,000 per month',
#        '₱35-40k base, ₱4K transport, ₱3,6K allowance',
#        '₱33,333 – ₱50,000 per month', 'Competitive base salary (USD)',
#        '₱65,000 – ₱75,000 per month', '₱75,000 – ₱100,000 per month',
#        '₱29,000 – ₱41,000 per month', '₱100,000 – ₱118,000 per month'],
#       dtype=object)

# %% [markdown]
# df['Salary'] = df['Salary'].fillna('unknown')

# %% [markdown]
# #### Salary format:
# - ₱{lower_lim_salary} - ₱{upper_lim_salary} per month
# - PHP{lower_lim_salary} to PHP{upper_lim_salary}
# - PHP{lower_lim_salary} - PHP{upper_lim_salary}
# - ₱{lower_lim_salary / upper_lim_salary} per month
# - {lower_lim_salary} to {upper_lim_salary}PHP
# - ₱{lower_lim_salary} - {upper_lim_salary}k base
#
# Each format has a common denominator of having an amount which could either indicate the lower salary range or fixed salary amount. If the salary is expressed as a range it could either be followed by "–","-", or "to" and the upper salary range. Currency of the salary can either be indicated before the range or after the range in the form of "PHP" or "₱"
#
# #### Building the general regex structure:
# r'(?:php|₱)*\s*([\d,]+)\s*(?:-|–|to)\s*(?:php|₱)*\s*([\d,]+)\s*(?:\s*per\s*(month|year))?\s*'
#
# A general salary format is used to handle conventional expressions of salary. This allows us to capture ranges that do not need further processing to log the correct information. I decided to divide the salary based on their case match to give me better tracking if there are new patterns that are not within the scope of the general regex.

# %% [raw]
# def parse_salary(s):
#     if pd.isna(s):
#         return (np.nan, np.nan, 'unknown', True, 0)
#
#     s = s.lower()
#
#     # Pattern 1: Budget - 20000 to 30000PHP
#     if match := re.search(r'budget\s*-\s*([\d,]+)\s*to\s*([\d,]+)\s*php', s):
#         return (int(match.group(1).replace(',', '')), int(match.group(2).replace(',', '')), 'unknown', False, 1)
#
#     # Pattern 2: ₱25,000 - ₱35,000 per month
#     if match := re.search(r'₱\s*([\d,]+)\s*[-–]\s*₱\s*([\d,]+)\s*per month', s):
#         return (int(match.group(1).replace(',', '')), int(match.group(2).replace(',', '')), 'monthly', False, 2)
#
#     # Pattern 3: PHP25,000 -/– PHP35,000
#     if match := re.search(r'php\s*([\d,]+)\s*[-–]\s*php\s*([\d,]+)', s):
#         return (int(match.group(1).replace(',', '')), int(match.group(2).replace(',', '')), 'unknown', False, 3)
#
#     # Pattern 4: PHP25,000 -/– 35,000
#     if match := re.search(r'php\s*([\d,]+)\s*[-–]\s*([\d,]+)', s):
#         return (int(match.group(1).replace(',', '')), int(match.group(2).replace(',', '')), 'unknown', False, 4)
#
#     # Pattern 5: PHP25,000 to PHP35,000
#     if match := re.search(r'php\s*([\d,]+)\s*to\s*php\s*([\d,]+)', s):
#         return (int(match.group(1).replace(',', '')), int(match.group(2).replace(',', '')), 'unknown', False, 5)
#
#     # Pattern 6: ₱25,000 per month (single value)
#     if match := re.search(r'₱\s*([\d,]+)\s*per month', s):
#         val = int(match.group(1).replace(',', ''))
#         return (val, val, 'monthly', False, 6)
#
#     # Pattern 7: ₱35-40k base, ₱4K transport, ₱3,6K allowance
#     if match := re.search(r'₱\s*([\d]+)\s*[-–]\s*([\d]+)\s*k?', s):
#         return (int(match.group(1))*1000, int(match.group(2))*1000, 'unknown', False, 7)
#
#     return (np.nan, np.nan, 'unknown', True, 0)

# %%
def parse_salary_test(s):
    #No salary informations is given
    if pd.isna(s):
        return (np.nan, np.nan, 'unknown', True, 0)
    
    s = s.lower()

    # Pattern 3: ₱35-40k base, ₱4K transport, ₱3,6K allowance (ranges expressed in thousands)
    if match := re.search(r'₱\s*([\d]+)\s*[-–]\s*([\d]+)\s*k?', s):
        return (int(match.group(1))*1000, int(match.group(2))*1000, 'unknown', False, 3)
        
    '''
    # Pattern A: ₱25,000 - ₱35,000 per month
    # Pattern B: PHP25,000 -/– PHP35,000
    # Pattern C: PHP25,000 -/– 35,000
    # Pattern D: PHP25,000 to PHP35,000
    # Pattern E: Budget - 20000 to 30000PHP
    '''
    
    #General Pattern (Covers patters A-E)
    if match := re.search(r'(?:php|₱)*\s*([\d,]+)\s*(?:-|–|to)\s*(?:php|₱)*\s*([\d,]+)\s*(?:php|₱)*\s*(?:\s*per\s*(month|year))?\s*', s):
        return (int(match.group(1).replace(',', '')), int(match.group(2).replace(',', '')), str(match.group(3)) +'ly' or 'unknown', False, 1)

    # Pattern 3: ₱25,000 per month (single value)
    if match := re.search(r'₱\s*([\d,]+)\s*per month', s):
        val = int(match.group(1).replace(',', ''))
        return (val, val, 'monthly', False, 4)
    
    # No number is present in salary information
    if match := re.search(r'\d{0}', s):
        return (np.nan, np.nan, 'unknown', False, 2)
    
    return (np.nan, np.nan, 'unknown', True, 0)

# %%
df[['salary_min', 'salary_max', 'salary_type', 'salary_unhandled', 'salary_pattern']] = df['Salary'].apply(
    lambda x: pd.Series(parse_salary_test(x))
)

# %%
df[(df['Salary'].notna()) & (df['salary_pattern'] == 4)]
# Out:
#              Date Obtained                                               Link  \
# 58        04/05/2025 22:18  https://ph.jobstreet.com/job/83890794?type=sta...
# 512    2025-05-05 13:35:21  https://ph.jobstreet.com/job/83890794?type=sta...
# 998    2025-05-06 21:34:52  https://ph.jobstreet.com/job/83890794?type=sta...
# 1494   2025-05-07 16:47:13  https://ph.jobstreet.com/job/83890794?type=sta...
# 2015   2025-05-08 17:30:06  https://ph.jobstreet.com/job/83890794?type=sta...
# 2538   2025-05-09 13:20:34  https://ph.jobstreet.com/job/83890794?type=sta...
# 3061   2025-05-10 14:43:42  https://ph.jobstreet.com/job/83890794?type=sta...
# 3578   2025-05-11 16:59:43  https://ph.jobstreet.com/job/83890794?type=sta...
# 4091   2025-05-12 21:06:18  https://ph.jobstreet.com/job/83890794?type=sta...
# 4613   2025-05-14 14:19:12  https://ph.jobstreet.com/job/83890794?type=sta...
# 5155   2025-05-15 22:19:55  https://ph.jobstreet.com/job/83890794?type=sta...
# 5670   2025-05-16 11:45:20  https://ph.jobstreet.com/job/83890794?type=sta...
# 6201   2025-05-17 17:13:35  https://ph.jobstreet.com/job/83890794?type=sta...
# 6724   2025-05-18 15:23:23  https://ph.jobstreet.com/job/83890794?type=sta...
# 7265   2025-05-19 19:29:52  https://ph.jobstreet.com/job/83890794?type=sta...
# 7506   2025-05-20 14:50:29  https://ph.jobstreet.com/job/84326289?type=sta...
# 7818   2025-05-20 14:50:29  https://ph.jobstreet.com/job/83890794?type=sta...
# 8089   2025-05-21 18:08:06  https://ph.jobstreet.com/job/84326289?type=sta...
# 8396   2025-05-21 18:08:06  https://ph.jobstreet.com/job/83890794?type=sta...
# 8676   2025-05-22 11:44:16  https://ph.jobstreet.com/job/84326289?type=sta...
# 8977   2025-05-22 11:44:16  https://ph.jobstreet.com/job/83890794?type=sta...
# 9281   2025-05-23 22:39:55  https://ph.jobstreet.com/job/84326289?type=sta...
# 9574   2025-05-23 22:39:55  https://ph.jobstreet.com/job/83890794?type=sta...
# 9850   2025-05-24 23:00:36  https://ph.jobstreet.com/job/84326289?type=sta...
# 10141  2025-05-24 23:00:36  https://ph.jobstreet.com/job/83890794?type=sta...
# 10392  2025-05-25 19:43:21  https://ph.jobstreet.com/job/84326289?type=sta...
# 10680  2025-05-25 19:43:21  https://ph.jobstreet.com/job/83890794?type=sta...
# 10935  2025-05-26 13:36:26  https://ph.jobstreet.com/job/84326289?type=sta...
# 11224  2025-05-26 13:36:26  https://ph.jobstreet.com/job/83890794?type=sta...
# 11490  2025-05-27 12:12:11  https://ph.jobstreet.com/job/84326289?type=sta...
# 11776  2025-05-27 12:12:11  https://ph.jobstreet.com/job/83890794?type=sta...
# 12066  2025-05-28 13:49:17  https://ph.jobstreet.com/job/84326289?type=sta...
# 12341  2025-05-28 13:49:17  https://ph.jobstreet.com/job/83890794?type=sta...
# 12659  2025-05-29 12:34:49  https://ph.jobstreet.com/job/84326289?type=sta...
# 12929  2025-05-29 12:34:49  https://ph.jobstreet.com/job/83890794?type=sta...
# 13274  2025-05-30 21:58:36  https://ph.jobstreet.com/job/84326289?type=sta...
# 13874  2025-05-31 11:37:57  https://ph.jobstreet.com/job/84326289?type=sta...
# 14452  2025-06-01 18:45:36  https://ph.jobstreet.com/job/84326289?type=sta...
# 15040  2025-06-02 14:19:42  https://ph.jobstreet.com/job/84326289?type=sta...
# 15628  2025-06-03 13:35:08  https://ph.jobstreet.com/job/84326289?type=sta...
# 16221  2025-06-04 12:47:46  https://ph.jobstreet.com/job/84326289?type=sta...
#
#                                          Company  \
# 58     POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 512    POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 998    POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 1494   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 2015   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 2538   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 3061   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 3578   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 4091   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 4613   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 5155   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 5670   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 6201   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 6724   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 7265   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 7506                        Scale-Up Philippines
# 7818   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 8089                        Scale-Up Philippines
# 8396   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 8676                        Scale-Up Philippines
# 8977   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 9281                        Scale-Up Philippines
# 9574   POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 9850                        Scale-Up Philippines
# 10141  POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 10392                       Scale-Up Philippines
# 10680  POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 10935                       Scale-Up Philippines
# 11224  POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 11490                       Scale-Up Philippines
# 11776  POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 12066                       Scale-Up Philippines
# 12341  POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 12659                       Scale-Up Philippines
# 12929  POLYTECHNIC UNIVERSITY OF THE PHILIPPINES
# 13274                       Scale-Up Philippines
# 13874                       Scale-Up Philippines
# 14452                       Scale-Up Philippines
# 15040                       Scale-Up Philippines
# 15628                       Scale-Up Philippines
# 16221                       Scale-Up Philippines
#
#                                                Position  \
# 58     Senior Statistical Specialist (SG-19, Job Order)
# 512    Senior Statistical Specialist (SG-19, Job Order)
# 998    Senior Statistical Specialist (SG-19, Job Order)
# 1494   Senior Statistical Specialist (SG-19, Job Order)
# 2015   Senior Statistical Specialist (SG-19, Job Order)
# 2538   Senior Statistical Specialist (SG-19, Job Order)
# 3061   Senior Statistical Specialist (SG-19, Job Order)
# 3578   Senior Statistical Specialist (SG-19, Job Order)
# 4091   Senior Statistical Specialist (SG-19, Job Order)
# 4613   Senior Statistical Specialist (SG-19, Job Order)
# 5155   Senior Statistical Specialist (SG-19, Job Order)
# 5670   Senior Statistical Specialist (SG-19, Job Order)
# 6201   Senior Statistical Specialist (SG-19, Job Order)
# 6724   Senior Statistical Specialist (SG-19, Job Order)
# 7265   Senior Statistical Specialist (SG-19, Job Order)
# 7506                             AI Specialist (Remote)
# 7818   Senior Statistical Specialist (SG-19, Job Order)
# 8089                             AI Specialist (Remote)
# 8396   Senior Statistical Specialist (SG-19, Job Order)
# 8676                             AI Specialist (Remote)
# 8977   Senior Statistical Specialist (SG-19, Job Order)
# 9281                             AI Specialist (Remote)
# 9574   Senior Statistical Specialist (SG-19, Job Order)
# 9850                             AI Specialist (Remote)
# 10141  Senior Statistical Specialist (SG-19, Job Order)
# 10392                            AI Specialist (Remote)
# 10680  Senior Statistical Specialist (SG-19, Job Order)
# 10935                            AI Specialist (Remote)
# 11224  Senior Statistical Specialist (SG-19, Job Order)
# 11490                            AI Specialist (Remote)
# 11776  Senior Statistical Specialist (SG-19, Job Order)
# 12066                            AI Specialist (Remote)
# 12341  Senior Statistical Specialist (SG-19, Job Order)
# 12659                            AI Specialist (Remote)
# 12929  Senior Statistical Specialist (SG-19, Job Order)
# 13274                            AI Specialist (Remote)
# 13874                            AI Specialist (Remote)
# 14452                            AI Specialist (Remote)
# 15040                            AI Specialist (Remote)
# 15628                            AI Specialist (Remote)
# 16221                            AI Specialist (Remote)
#
#                        Location                  Classification  \
# 58     Santa Mesa, Metro Manila  Customer Service - Call Centre
# 512    Santa Mesa, Metro Manila  Customer Service - Call Centre
# 998    Santa Mesa, Metro Manila  Customer Service - Call Centre
# 1494   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 2015   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 2538   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 3061   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 3578   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 4091   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 4613   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 5155   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 5670   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 6201   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 6724   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 7265   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 7506               Metro Manila                     Consultants
# 7818   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 8089               Metro Manila                     Consultants
# 8396   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 8676               Metro Manila                     Consultants
# 8977   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 9281               Metro Manila                     Consultants
# 9574   Santa Mesa, Metro Manila  Customer Service - Call Centre
# 9850               Metro Manila                     Consultants
# 10141  Santa Mesa, Metro Manila  Customer Service - Call Centre
# 10392              Metro Manila                     Consultants
# 10680  Santa Mesa, Metro Manila  Customer Service - Call Centre
# 10935              Metro Manila                     Consultants
# 11224  Santa Mesa, Metro Manila  Customer Service - Call Centre
# 11490              Metro Manila                     Consultants
# 11776  Santa Mesa, Metro Manila  Customer Service - Call Centre
# 12066              Metro Manila                     Consultants
# 12341  Santa Mesa, Metro Manila  Customer Service - Call Centre
# 12659              Metro Manila                     Consultants
# 12929  Santa Mesa, Metro Manila  Customer Service - Call Centre
# 13274              Metro Manila                     Consultants
# 13874              Metro Manila                     Consultants
# 14452              Metro Manila                     Consultants
# 15040              Metro Manila                     Consultants
# 15628              Metro Manila                     Consultants
# 16221              Metro Manila                     Consultants
#
#                                      Industry             Salary  \
# 58             Call Centre & Customer Service  ₱59,260 per month
# 512            Call Centre & Customer Service  ₱59,260 per month
# 998            Call Centre & Customer Service  ₱59,260 per month
# 1494           Call Centre & Customer Service  ₱59,260 per month
# 2015           Call Centre & Customer Service  ₱59,260 per month
# 2538           Call Centre & Customer Service  ₱59,260 per month
# 3061           Call Centre & Customer Service  ₱59,260 per month
# 3578           Call Centre & Customer Service  ₱59,260 per month
# 4091           Call Centre & Customer Service  ₱59,260 per month
# 4613           Call Centre & Customer Service  ₱59,260 per month
# 5155           Call Centre & Customer Service  ₱59,260 per month
# 5670           Call Centre & Customer Service  ₱59,260 per month
# 6201           Call Centre & Customer Service  ₱59,260 per month
# 6724           Call Centre & Customer Service  ₱59,260 per month
# 7265           Call Centre & Customer Service  ₱59,260 per month
# 7506   Information & Communication Technology  ₱25,000 per month
# 7818           Call Centre & Customer Service  ₱59,260 per month
# 8089   Information & Communication Technology  ₱25,000 per month
# 8396           Call Centre & Customer Service  ₱59,260 per month
# 8676   Information & Communication Technology  ₱25,000 per month
# 8977           Call Centre & Customer Service  ₱59,260 per month
# 9281   Information & Communication Technology  ₱25,000 per month
# 9574           Call Centre & Customer Service  ₱59,260 per month
# 9850   Information & Communication Technology  ₱25,000 per month
# 10141          Call Centre & Customer Service  ₱59,260 per month
# 10392  Information & Communication Technology  ₱25,000 per month
# 10680          Call Centre & Customer Service  ₱59,260 per month
# 10935  Information & Communication Technology  ₱25,000 per month
# 11224          Call Centre & Customer Service  ₱59,260 per month
# 11490  Information & Communication Technology  ₱25,000 per month
# 11776          Call Centre & Customer Service  ₱59,260 per month
# 12066  Information & Communication Technology  ₱25,000 per month
# 12341          Call Centre & Customer Service  ₱59,260 per month
# 12659  Information & Communication Technology  ₱25,000 per month
# 12929          Call Centre & Customer Service  ₱59,260 per month
# 13274  Information & Communication Technology  ₱25,000 per month
# 13874  Information & Communication Technology  ₱25,000 per month
# 14452  Information & Communication Technology  ₱25,000 per month
# 15040  Information & Communication Technology  ₱25,000 per month
# 15628  Information & Communication Technology  ₱25,000 per month
# 16221  Information & Communication Technology  ₱25,000 per month
#
#       Work Arrangement Day Posted    Job ID  salary_min  salary_max  \
# 58               Other     5d ago  83890794     59260.0     59260.0
# 512              Other     5d ago  83890794     59260.0     59260.0
# 998              Other     7d ago  83890794     59260.0     59260.0
# 1494             Other     7d ago  83890794     59260.0     59260.0
# 2015             Other     9d ago  83890794     59260.0     59260.0
# 2538             Other     9d ago  83890794     59260.0     59260.0
# 3061             Other    10d ago  83890794     59260.0     59260.0
# 3578             Other    11d ago  83890794     59260.0     59260.0
# 4091             Other    13d ago  83890794     59260.0     59260.0
# 4613             Other    14d ago  83890794     59260.0     59260.0
# 5155             Other    16d ago  83890794     59260.0     59260.0
# 5670             Other    16d ago  83890794     59260.0     59260.0
# 6201             Other    17d ago  83890794     59260.0     59260.0
# 6724             Other    18d ago  83890794     59260.0     59260.0
# 7265             Other    20d ago  83890794     59260.0     59260.0
# 7506            Remote    16h ago  84326289     25000.0     25000.0
# 7818             Other    20d ago  83890794     59260.0     59260.0
# 8089            Remote     1d ago  84326289     25000.0     25000.0
# 8396             Other    22d ago  83890794     59260.0     59260.0
# 8676            Remote     2d ago  84326289     25000.0     25000.0
# 8977             Other    22d ago  83890794     59260.0     59260.0
# 9281            Remote     4d ago  84326289     25000.0     25000.0
# 9574             Other    24d ago  83890794     59260.0     59260.0
# 9850            Remote     5d ago  84326289     25000.0     25000.0
# 10141            Other    25d ago  83890794     59260.0     59260.0
# 10392           Remote     5d ago  84326289     25000.0     25000.0
# 10680            Other    26d ago  83890794     59260.0     59260.0
# 10935           Remote     6d ago  84326289     25000.0     25000.0
# 11224            Other    26d ago  83890794     59260.0     59260.0
# 11490           Remote     7d ago  84326289     25000.0     25000.0
# 11776            Other    27d ago  83890794     59260.0     59260.0
# 12066           Remote     8d ago  84326289     25000.0     25000.0
# 12341            Other    28d ago  83890794     59260.0     59260.0
# 12659           Remote     9d ago  84326289     25000.0     25000.0
# 12929            Other    29d ago  83890794     59260.0     59260.0
# 13274           Remote    10d ago  84326289     25000.0     25000.0
# 13874           Remote    11d ago  84326289     25000.0     25000.0
# 14452           Remote    12d ago  84326289     25000.0     25000.0
# 15040           Remote    13d ago  84326289     25000.0     25000.0
# 15628           Remote    14d ago  84326289     25000.0     25000.0
# 16221           Remote    15d ago  84326289     25000.0     25000.0
#
#       salary_type  salary_unhandled  salary_pattern
# 58        monthly             False               4
# 512       monthly             False               4
# 998       monthly             False               4
# 1494      monthly             False               4
# 2015      monthly             False               4
# 2538      monthly             False               4
# 3061      monthly             False               4
# 3578      monthly             False               4
# 4091      monthly             False               4
# 4613      monthly             False               4
# 5155      monthly             False               4
# 5670      monthly             False               4
# 6201      monthly             False               4
# 6724      monthly             False               4
# 7265      monthly             False               4
# 7506      monthly             False               4
# 7818      monthly             False               4
# 8089      monthly             False               4
# 8396      monthly             False               4
# 8676      monthly             False               4
# 8977      monthly             False               4
# 9281      monthly             False               4
# 9574      monthly             False               4
# 9850      monthly             False               4
# 10141     monthly             False               4
# 10392     monthly             False               4
# 10680     monthly             False               4
# 10935     monthly             False               4
# 11224     monthly             False               4
# 11490     monthly             False               4
# 11776     monthly             False               4
# 12066     monthly             False               4
# 12341     monthly             False               4
# 12659     monthly             False               4
# 12929     monthly             False               4
# 13274     monthly             False               4
# 13874     monthly             False               4
# 14452     monthly             False               4
# 15040     monthly             False               4
# 15628     monthly             False               4
# 16221     monthly             False               4

# %% [markdown]
# ### Creating Date posted from Date Obtained and Day Posted

# %% [markdown]
# My scraped data only contains the date when it was obtained and the relative time that it was posted on Jobstreet. Our transformation should handle the computation of its estimated post date. Estimated is emphasized since we will be encountering job posts that are posted 30d+ ago. It could range from 31 days up to months. To get these information, it would be best to log unique job posts on a separate table where we will then get the post date. Any succeeding occurence of this job post would add up to the days posted counter since we are sure that only the relative date will change upon its recurrence.

# %%
df.dtypes
# Out:
# Date Obtained        object
# Link                 object
# Company              object
# Position             object
# Location             object
# Classification       object
# Industry             object
# Salary               object
# Work Arrangement     object
# Day Posted           object
# Job ID               object
# salary_min          float64
# salary_max          float64
# salary_type          object
# salary_unhandled       bool
# salary_pattern        int64
# dtype: object

# %%
df['Date Obtained'] = pd.to_datetime(df['Date Obtained'])

# %%
df['Day Posted'].unique()
# Out:
# array(['13h ago', '1d ago', '2d ago', '3d ago', '4d ago', '5d ago',
#        '6d ago', '8d ago', '9d ago', '10d ago', '11d ago', '12d ago',
#        '13d ago', '15d ago', '16d ago', '17d ago', '18d ago', '19d ago',
#        '20d ago', '21d ago', '22d ago', '23d ago', '24d ago', '25d ago',
#        '26d ago', '27d ago', '29d ago', '30d+ ago', '7m ago', '55m ago',
#        '58m ago', '1h ago', '2h ago', '3h ago', '6h ago', '7d ago',
#        '14d ago', '28d ago', '5h ago', '8h ago', '10h ago', '11h ago',
#        '20h ago', '21h ago', '22h ago', '10m ago', '11m ago', '18m ago',
#        '4h ago', '16h ago', '18h ago', '7h ago', '9h ago', '14h ago',
#        '19h ago', '23h ago', '15h ago', '17h ago', '38m ago', '35m ago',
#        '32m ago', '12h ago', '23m ago', '6m ago', '24m ago', '57m ago',
#        '22m ago', '27m ago', '17m ago', '51m ago', '52m ago', '53m ago',
#        '42m ago', '14m ago', '20m ago', '59m ago'], dtype=object)

# %%
df[df['Day Posted'] == '30d+ ago'].sort_values('Date Obtained', ascending = False)
# Out:
#             Date Obtained                                               Link  \
# 16527 2025-06-04 12:47:46  https://ph.jobstreet.com/job/77220481?type=sta...
# 16460 2025-06-04 12:47:46  https://ph.jobstreet.com/job/83618425?type=sta...
# 16449 2025-06-04 12:47:46  https://ph.jobstreet.com/job/83802999?type=sta...
# 16450 2025-06-04 12:47:46  https://ph.jobstreet.com/job/83947053?type=sta...
# 16451 2025-06-04 12:47:46  https://ph.jobstreet.com/job/83813313?type=sta...
# ...                   ...                                                ...
# 415   2025-04-05 22:18:00  https://ph.jobstreet.com/job/78989457?type=sta...
# 416   2025-04-05 22:18:00  https://ph.jobstreet.com/job/79572930?type=sta...
# 417   2025-04-05 22:18:00  https://ph.jobstreet.com/job/78818835?type=sta...
# 418   2025-04-05 22:18:00  https://ph.jobstreet.com/job/78759264?type=sta...
# 347   2025-04-05 22:18:00  https://ph.jobstreet.com/job/83301526?type=sta...
#
#                                               Company  \
# 16527                                        FullTeam
# 16460  Citigroup Business Process Solutions Pte. Ltd.
# 16449                                       Accenture
# 16450                                Thakral One Inc.
# 16451                                Thakral One Inc.
# ...                                               ...
# 415                 Metropolitan Bank & Trust Company
# 416                     KSearch Asia Consulting, Inc.
# 417                                   Elevated Hiring
# 418                                   Panoptik Global
# 347                 SAS Institute (Philippines), Inc.
#
#                                          Position                   Location  \
# 16527                               Data Engineer               Metro Manila
# 16460        AVP, Risk Model Sr. Analyst (Hybrid)    Santa Ana, Metro Manila
# 16449   DE027776 - Analytics and Modeling Analyst    Santa Ana, Metro Manila
# 16450         Data Scientist - Telecommunications  Manila City, Metro Manila
# 16451  Senior Data Scientist - Financial Services  Manila City, Metro Manila
# ...                                           ...                        ...
# 415                         Data Quality Engineer    Santa Ana, Metro Manila
# 416                      Principal Data Scientist  Manila City, Metro Manila
# 417                               AP-Data Analyst  Manila City, Metro Manila
# 418                Data Engineer - Data Warehouse  Quezon City, Metro Manila
# 347      Requisition Title Technical Consultant-3  Manila City, Metro Manila
#
#                                        Classification  \
# 16527                          Developers/Programmers
# 16460                            Analysis & Reporting
# 16449                          Developers/Programmers
# 16450  Mathematics, Statistics & Information Sciences
# 16451  Mathematics, Statistics & Information Sciences
# ...                                               ...
# 415                            Engineering - Software
# 416    Mathematics, Statistics & Information Sciences
# 417    Mathematics, Statistics & Information Sciences
# 418                            Developers/Programmers
# 347                            Engineering - Software
#
#                                      Industry Salary Work Arrangement  \
# 16527  Information & Communication Technology    NaN           Hybrid
# 16460            Banking & Financial Services    NaN           Hybrid
# 16449  Information & Communication Technology    NaN           Hybrid
# 16450                    Science & Technology    NaN            Other
# 16451                    Science & Technology    NaN            Other
# ...                                       ...    ...              ...
# 415    Information & Communication Technology    NaN            Other
# 416                      Science & Technology    NaN            Other
# 417                      Science & Technology    NaN            Other
# 418    Information & Communication Technology    NaN           Hybrid
# 347    Information & Communication Technology    NaN           Hybrid
#
#       Day Posted    Job ID  salary_min  salary_max salary_type  \
# 16527   30d+ ago  77220481         NaN         NaN     unknown
# 16460   30d+ ago  83618425         NaN         NaN     unknown
# 16449   30d+ ago  83802999         NaN         NaN     unknown
# 16450   30d+ ago  83947053         NaN         NaN     unknown
# 16451   30d+ ago  83813313         NaN         NaN     unknown
# ...          ...       ...         ...         ...         ...
# 415     30d+ ago  78989457         NaN         NaN     unknown
# 416     30d+ ago  79572930         NaN         NaN     unknown
# 417     30d+ ago  78818835         NaN         NaN     unknown
# 418     30d+ ago  78759264         NaN         NaN     unknown
# 347     30d+ ago  83301526         NaN         NaN     unknown
#
#        salary_unhandled  salary_pattern
# 16527              True               0
# 16460              True               0
# 16449              True               0
# 16450              True               0
# 16451              True               0
# ...                 ...             ...
# 415                True               0
# 416                True               0
# 417                True               0
# 418                True               0
# 347                True               0
#
# [3217 rows x 16 columns]

# %%
df_unique = pd.DataFrame()
df_transformed = df.copy()
df_transformed.rename(columns = {'Job ID': "job_id"}, inplace =True)

# %%
def sort_unique_job_id(df_transformed, df_unique):
    
    jobs_by_date = df_transformed.sort_values(by = 'Date Obtained', ascending = True)
    unique_jobs = jobs_by_date.drop_duplicates(subset = 'job_id', keep = 'first')

    if not df_unique.empty:
    
        logged_unique_ids = set(df_unique['job_id'])
        unique_jobs = unique_jobs[~unique_jobs['job_id'].isin(logged_unique_ids)]

    df_unique = pd.concat([df_unique, unique_jobs], ignore_index = True)
    df_unique = df_unique.drop(columns = ['Company','Position','Location','Classification','Industry','Salary','Work Arrangement',
                                          'salary_min','salary_max','salary_type','salary_unhandled','salary_pattern'])

    return df_unique

# %%
df_transformed.dtypes
# Out:
# Date Obtained       datetime64[ns]
# Link                        object
# Company                     object
# Position                    object
# Location                    object
# Classification              object
# Industry                    object
# Salary                      object
# Work Arrangement            object
# Day Posted                  object
# job_id                      object
# salary_min                 float64
# salary_max                 float64
# salary_type                 object
# salary_unhandled              bool
# salary_pattern               int64
# dtype: object

# %%
df_unique = sort_unique_job_id(df_transformed, df_unique)

# %% [markdown]
# df_unique['Date Obtained'] = pd.to_datetime(df_unique['Date Obtained'])

# %%
def get_job_postdate (day_posted, time_ref):
    time_regex = r'(\d+)(m|d|h)(\+)?'

    relative_date = day_posted.lower().strip()

    match = re.search(time_regex, relative_date)
    if not match or match.group(3):
        return None
    
    if match.group(2) == 'm':
        return time_ref - timedelta(minutes = int(match.group(1)))
    elif match.group(2) == 'h':
        return time_ref - timedelta(hours = int(match.group(1)))
    elif match.group(2) == 'd':
        return time_ref - timedelta(days = int(match.group(1)))
    else:
        return None

# %%
df_unique['post_date'] = pd.to_datetime(df_unique.apply(
    lambda x:get_job_postdate (x['Day Posted'], time_ref = x['Date Obtained']),
    axis = 1
))

# %%
df_unique[df_unique['Day Posted'] == '30d+ ago']['job_id'].unique()
# Out:
# array(['78989457', '80037393', '79004435', '79151153', '79341544',
#        '79526144', '79687091', '79736502', '79815064', '79985682',
#        '80218076', '79572930', '80194431', '80256246', '80254607',
#        '80401872', '80665449', '82889675', '80946367', '81115059',
#        '81366983', '81470641', '81517096', '81938855', '80245355',
#        '82493696', '78818835', '78691483', '75699671', '76333561',
#        '76594626', '76633426', '76328782', '77220481', '76625639',
#        '76627039', '76758796', '76744105', '76759028', '78759264',
#        '76935616', '76987283', '79362904', '76987241', '76994034',
#        '76997351', '77058756', '77188091', '77478438', '77541455',
#        '79665148', '77827947', '77634075', '81861895', '82052309',
#        '83180789', '83189978', '83200178', '83200346', '83199380',
#        '83208112', '83226061', '83226324', '83240193', '83851760',
#        '83301229', '83181036', '83300550', '83301526', '82028870',
#        '83151728', '83143862', '83134738', '83851844', '83134622',
#        '83134795', '82319886', '82391615', '82451927', '82451854',
#        '82618424', '82716110', '82696502', '83347225', '82721568',
#        '82889752', '82889206', '82913665', '82942574', '83013342',
#        '83760955', '83021755', '83147458', '83075712', '83078944',
#        '82786806', '82796121', '83297778', '81867471', '83382749',
#        '81920005', '79666130', '82626658', '84237827', '81605177',
#        '79496830', '81866641', '84514041', '84571608', '84642989',
#        '83694301', '84642307'], dtype=object)

# %%
df_unique.head()
# Out:
#         Date Obtained                                               Link  \
# 0 2025-04-05 22:18:00  https://ph.jobstreet.com/job/83980792?type=sta...
# 1 2025-04-05 22:18:00  https://ph.jobstreet.com/job/83403318?type=sta...
# 2 2025-04-05 22:18:00  https://ph.jobstreet.com/job/83418034?type=sta...
# 3 2025-04-05 22:18:00  https://ph.jobstreet.com/job/83420593?type=sta...
# 4 2025-04-05 22:18:00  https://ph.jobstreet.com/job/83420600?type=sta...
#
#   Day Posted    job_id           post_date
# 0    13h ago  83980792 2025-04-05 09:18:00
# 1    25d ago  83403318 2025-03-11 22:18:00
# 2    25d ago  83418034 2025-03-11 22:18:00
# 3    24d ago  83420593 2025-03-12 22:18:00
# 4    24d ago  83420600 2025-03-12 22:18:00

# %%
df_unique.to_csv('unique_jobs.csv', index = False)
df_transformed.to_csv('transformed_jobstreet_jobs.csv', index = False, encoding='utf-8-sig')
